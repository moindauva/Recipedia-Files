# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Sun_Feb_14_21:12:58_PST_2021
# Cuda compilation tools, release 11.2, V11.2.152
# Build cuda_11.2.r11.2/compiler.29618528_0

# %%
# !unzip "/content/drive/My Drive/FYP/darknet.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: build/darknet/x64/data/labels/84_1.png
#   inflating: build/darknet/x64/data/labels/84_2.png
#   inflating: build/darknet/x64/data/labels/84_3.png
#   inflating: build/darknet/x64/data/labels/84_4.png
#   inflating: build/darknet/x64/data/labels/84_5.png
#   inflating: build/darknet/x64/data/labels/84_6.png
#   inflating: build/darknet/x64/data/labels/84_7.png
#   inflating: build/darknet/x64/data/labels/85_0.png
#   inflating: build/darknet/x64/data/labels/85_1.png
#   inflating: build/darknet/x64/data/labels/85_2.png
#   inflating: build/darknet/x64/data/labels/85_3.png
#   inflating: build/darknet/x64/data/labels/85_4.png
#   inflating: build/darknet/x64/data/labels/85_5.png
#   inflating: build/darknet/x64/data/labels/85_6.png
#   inflating: build/darknet/x64/data/labels/85_7.png
#   inflating: build/darknet/x64/data/labels/86_0.png
#   inflating: build/darknet/x64/data/labels/86_1.png
# ...

# %%
# %cd /content/drive/MyDrive/FYP/darknet

# !make 
# !chmod +x ./darknet
# Out:
# /content/drive/MyDrive/FYP/darknet
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# !rm /content/drive/MyDrive/FYP/darknet/backup -r
# !ln -s /content/drive/MyDrive/FYP/backup /content/drive/MyDrive/FYP/darknet
# Out:
# rm: cannot remove '/content/drive/MyDrive/FYP/darknet/backup': No such file or directory

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 21 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 0s (3,880 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
# !dos2unix data/train.txt.txt
# !dos2unix data/val.txt.txt
# !dos2unix data/yolo.data
# !dos2unix data/images/yolo.names
# !dos2unix cfg/yolov3_custom_train.cfg
# Out:
# dos2unix: converting file data/train.txt.txt to Unix format...
# dos2unix: converting file data/val.txt.txt to Unix format...
# dos2unix: converting file data/yolo.data to Unix format...
# dos2unix: data/images/yolo.names: No such file or directory
# dos2unix: Skipping data/images/yolo.names, not a regular file.
# dos2unix: converting file cfg/yolov3_custom_train.cfg to Unix format...

# %%
# %cd /content/drive/MyDrive/FYP/darknet
# !ls
# !./darknet detector train data/yolo.data cfg/yolov3_custom_train.cfg darknet53.conv.74 -dont_show

# %%
# %cd /content/drive/MyDrive/FYP/darknet/
# !ls
# !./darknet detector train data/yolo.data cfg/yolov3_custom_train.cfg /content/drive/MyDrive/FYP/darknet/backup/yolov3_custom_train_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 278081, rewritten_bbox = 0.033803 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.742690), count: 4, class_loss = 1.571152, iou_loss = 1.115180, total_loss = 2.686332
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000182, iou_loss = 0.000000, total_loss = 0.000182
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000020, iou_loss = 0.000000, total_loss = 0.000020
#  total_bbox = 278085, rewritten_bbox = 0.033803 %
# ...
